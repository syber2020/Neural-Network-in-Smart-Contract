# %%
import numpy as np
import pandas as pd

# %%
def sigmoidfrac1(x,y):
    if(x/y>=10):
        num = 1; den = 1
    elif((x/y)>=9 and (x/y)<10):
        num = 99988; den = 100000
    elif((x/y)>=8 and (x/y)<9):
        num = 99966; den = 100000
    elif((x/y)>=7 and (x/y)<8):
        num = 99909; den = 100000
    elif((x/y)>=6 and (x/y)<7):
        num = 99753; den = 100000
    elif((x/y)>=5 and (x/y)<6):
        num = 99331; den = 100000
    elif((x/y)>=1 and (x/y)<5):
        q = int(x/y) 
        r = x%y
        num= pow(19,q)*24*pow(y,4)
        den= pow(19,q)*24*pow(y,4)+pow(7,q)*(24*pow(y,4)-24*r*pow(y,3)+12*pow(r,2)*pow(y,2)-4*y*pow(r,3)+pow(r,4))    
    elif(x/y>-1 and x/y<1):
        num= 24*pow(y,4)
        den= 48*pow(y,4)-24*x*pow(y,3)+12*pow(x,2)*pow(y,2)-4*y*pow(x,3)+pow(x,4)   
    elif(x/y>-6 and x/y<=-1):
        q = int(x/y) 
        r = x%y
        num = 24*pow(y,4)*pow(7,-q)
        den = 24*pow(y,4)*pow(7,-q)+pow(19,-q)*(24*pow(y,4)+24*r*pow(y,3)+12*pow(r,2)*pow(y,2)+4*y*pow(r,3)+pow(r,4))
    elif(x/y>-7 and x/y<=-6):
        num =15; den= 10000 
    elif(x/y>-8 and x/y<=-7):
        num =6; den = 10000     
    elif(x/y>-9 and x/y<=-8):
        num =2; den = 10000 
    elif(x/y>-10 and x/y<=-9):
         num = 7; den = 100000
    elif(x/y<=-10):
         num = 0 ; den =1
    print(num,den)
    return num,den

# %%
def sigmoidfrac2(x,y):
    print(x,y)
    if(x/y>=10):
        num = 1; den = 1
    elif((x/y)>=9 and (x/y)<10):
        num = 99988; den = 100000
    elif((x/y)>=8 and (x/y)<9):
        num = 99966; den = 100000
    elif((x/y)>=7 and (x/y)<8):
        num = 99909; den = 100000
    elif((x/y)>=6 and (x/y)<7):
        num = 99753; den = 100000
    elif((x/y)>=5 and (x/y)<6):
        num = 99331; den = 100000
    elif((x/y)>=1 and (x/y)<5):
        q = int(x/y) 
        r = x%y
        num= pow(19,q)*24*pow(y,4)
        den= pow(19,q)*24*pow(y,4)+pow(7,q)*(24*pow(y,4)-24*r*pow(y,3)+12*pow(r,2)*pow(y,2)-4*y*pow(r,3)+pow(r,4))    
   
    elif(x/y>0 and x/y<1):
        print("this is triggered when x/y is greater than 0 and less than 1")
        num= 24*pow(y,4)
        den= 48*pow(y,4)-24*x*pow(y,3)+12*pow(x,2)*pow(y,2)-4*y*pow(x,3)+pow(x,4)
        
    
    elif(x/y>-1 and x/y<0):
        x = x * (-1) ## this is beacuse we have coded the program in this manner to take positive input becasue solidity does not work with negative power 
        print(" this is triggered when x/y is > -1 and less than 0")
        num= 24*pow(y,4)
        den= 48*pow(y,4)+24*x*pow(y,3)+12*pow(x,2)*pow(y,2)+4*y*pow(x,3)+pow(x,4)
        print(num,den)
        # this works fine
    elif(x/y>-6 and x/y<=-1):
        x = x*(-1)
        q = int(x/y)     
        r = x%y
        print( " q and r is ", q,r)
        num = 24*pow(y,4)*pow(7,q)
        den = 24*pow(y,4)*pow(7,q)+pow(19,q)*(24*pow(y,4)+24*r*pow(y,3)+12*pow(r,2)*pow(y,2)+4*y*pow(r,3)+pow(r,4))
    elif(x/y>-7 and x/y<=-6):
        num =15; den= 10000 
    elif(x/y>-8 and x/y<=-7):
        num =6; den = 10000     
    elif(x/y>-9 and x/y<=-8):
        num =2; den = 10000 
    elif(x/y>-10 and x/y<=-9):
         num = 7; den = 100000
    elif(x/y<=-10):
         num = 0 ; den =1
    print(num,den)
    return num,den

# %%
#consider value of x is positive
def sigmoidfrac_pos(x,y):
    if(x/y>=10):
        num = 1; den = 1
    elif((x/y)>=9 and (x/y)<10):
        num = 99988; den = 100000
    elif((x/y)>=8 and (x/y)<9):
        num = 99966; den = 100000
    elif((x/y)>=7 and (x/y)<8):
        num = 99909; den = 100000
    elif((x/y)>=6 and (x/y)<7):
        num = 99753; den = 100000
    elif((x/y)>=5 and (x/y)<6):
        num = 99331; den = 100000
    elif((x/y)>=1 and (x/y)<5):
        q = int(x/y) 
        r = x%y
        num= pow(19,q)*24*pow(y,4)
        den= pow(19,q)*24*pow(y,4)+pow(7,q)*(24*pow(y,4)-24*r*pow(y,3)+12*pow(r,2)*pow(y,2)-4*y*pow(r,3)+pow(r,4))    
    elif(x<y and x>0):
        print("this is triggered when x/y is greater than 0 and less than 1")
        num= 24*pow(y,4)
        den= 48*pow(y,4)-24*x*pow(y,3)+12*pow(x,2)*pow(y,2)-4*y*pow(x,3)+pow(x,4)
    print(num,den)
    return num,den

# %%
# considering value of x is negative 
def sigmoidfrac_neg(x,y):
    print(x,y)
    if(x<y and x>0):
         ## this is beacuse we have coded the program in this manner to take positive input becasue solidity does not work with negative power 
        print(" this is triggered when x/y is > -1 and less than 0")
        num= 24*pow(y,4)
        den= 48*pow(y,4)+24*x*pow(y,3)+12*pow(x,2)*pow(y,2)+4*y*pow(x,3)+pow(x,4)
        print(num,den)
        # this works fine
    elif(x/y>6 and x/y<=1):
#         x = x*(-1)
        q = int(x/y)     
        r = x%y
        print( " q and r is ", q,r)
        num = 24*pow(y,4)*pow(7,q)
        den = 24*pow(y,4)*pow(7,q)+pow(19,q)*(24*pow(y,4)+24*r*pow(y,3)+12*pow(r,2)*pow(y,2)+4*y*pow(r,3)+pow(r,4))
    elif(x/y>6 and x/y<=7):
        num =15; den= 10000 
    elif(x/y>7 and x/y<=8):
        print("x/y >7 and x/y<8")
        num =6; den = 10000     
    elif(x/y>8 and x/y<=9):
        num =2; den = 10000 
    elif(x/y>9 and x/y<=10):
        num = 7; den = 100000
    else:
        num = 0 ; den =1
    print(num,den)
    return num,den

# %%
a = -30; b = 4
if (a<0):
    a = a*-1
    sigmoidfrac_neg(a,b)
else:
    sigmoidfrac_pos(a,b)
# Out:
# 30 4
# x/y >8 and
# 6 10000
